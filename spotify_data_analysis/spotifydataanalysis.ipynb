# %%
import pandas as pd

# %%
data = 'spotify-2023.xlsx'
pd.read_excel(data)
# Out:
#                     track_name      artist(s)_name  artist_count  \
# 0            Seven(feat.LATTO)    Latto, Jung Kook           2.0
# 1                         LALA         Myke Towers           1.0
# 2                      Vampire      Olivia Rodrigo           1.0
# 3                 Cruel Summer        Taylor Swift           1.0
# 4               WHERE SHE GOES           Bad Bunny           1.0
# ..                         ...                 ...           ...
# 949               My Mind & Me        Taylor Swift           1.0
# 950  Bigger Than The Whole Sky  Feid, Paulo Londra           2.0
# 951       A Veces (feat. Feid)  Feid, Sech, Jhayco           3.0
# 952              En La De Ella           Burna Boy           1.0
# 953                      Alone                 NaN           NaN
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023.0             7.0          14.0                 553.0
# ...
