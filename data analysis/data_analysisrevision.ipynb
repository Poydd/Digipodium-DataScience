# %%
import plotly.express as px
import seaborn as sns
import numpy as np

# %%
planets  = sns.load_dataset('planets')
planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
p = planets.groupby('method')['mass'].max()

# %%
p.replace(np.nan, 0)
# Out:
# method
# Astrometry                        0.00
# Eclipse Timing Variations         6.05
# Imaging                           0.00
# Microlensing                      0.00
# Orbital Brightness Modulation     0.00
# Pulsar Timing                     0.00
# Pulsation Timing Variations       0.00
# Radial Velocity                  25.00
# Transit                           1.47
# Transit Timing Variations         0.00
# Name: mass, dtype: float64

# %%
p.replace(np.nan, 0, inplace=True)
p = p.astype(int)
p
# Out:
# method
# Astrometry                        0
# Eclipse Timing Variations         6
# Imaging                           0
# Microlensing                      0
# Orbital Brightness Modulation     0
# Pulsar Timing                     0
# Pulsation Timing Variations       0
# Radial Velocity                  25
# Transit                           1
# Transit Timing Variations         0
# Name: mass, dtype: int32

# %%
planets.pivot_table(values='orbital_period',index='method',columns='year',aggfunc='sum').plot(kind='bar')
# Out:
# <Axes: xlabel='method'>

# %%
planets.sort_values(by='year', ascending=False)
# Out:
#               method  number  orbital_period    mass  distance  year
# 852          Transit       4       43.844500     NaN       NaN  2014
# 890          Transit       2        2.426290     NaN       NaN  2014
# 440  Radial Velocity       1     3827.000000   0.480     20.48  2014
# 895          Transit       1       68.958400     NaN       NaN  2014
# 894          Transit       1        2.465020     NaN       NaN  2014
# ..               ...     ...             ...     ...       ...   ...
# 16   Radial Velocity       1        4.230785   0.472     15.36  1995
# 943    Pulsar Timing       3       98.211400     NaN       NaN  1994
# 941    Pulsar Timing       3       25.262000     NaN       NaN  1992
# 942    Pulsar Timing       3       66.541900     NaN       NaN  1992
# 441  Radial Velocity       1       83.888000  11.680     40.57  1989
#
# [1035 rows x 6 columns]

# %%
planets.groupby(['method'])[['year','mass']].sum()
# Out:
#                                   year        mass
# method
# Astrometry                        4023     0.00000
# Eclipse Timing Variations        18090    10.25000
# Imaging                          76347     0.00000
# Microlensing                     46225     0.00000
# Orbital Brightness Modulation     6035     0.00000
# Pulsar Timing                     9992     0.00000
# Pulsation Timing Variations       2007     0.00000
# Radial Velocity                1110158  1341.65638
# Transit                         798461     1.47000
# Transit Timing Variations         8050     0.00000

# %%
planets.groupby(['method'])[['year','mass']].max()
# Out:
#                                year   mass
# method
# Astrometry                     2013    NaN
# Eclipse Timing Variations      2012   6.05
# Imaging                        2013    NaN
# Microlensing                   2013    NaN
# Orbital Brightness Modulation  2013    NaN
# Pulsar Timing                  2011    NaN
# Pulsation Timing Variations    2007    NaN
# Radial Velocity                2014  25.00
# Transit                        2014   1.47
# Transit Timing Variations      2014    NaN

# %%
planets.groupby(['method'])[['year','mass']].min()
# Out:
#                                year    mass
# method
# Astrometry                     2010     NaN
# Eclipse Timing Variations      2008  4.2000
# Imaging                        2004     NaN
# Microlensing                   2004     NaN
# Orbital Brightness Modulation  2011     NaN
# Pulsar Timing                  1992     NaN
# Pulsation Timing Variations    2007     NaN
# Radial Velocity                1989  0.0036
# Transit                        2002  1.4700
# Transit Timing Variations      2011     NaN

# %%
planets.groupby(['method'])[['year','mass']].mean()
# Out:
#                                       year      mass
# method
# Astrometry                     2011.500000       NaN
# Eclipse Timing Variations      2010.000000  5.125000
# Imaging                        2009.131579       NaN
# Microlensing                   2009.782609       NaN
# Orbital Brightness Modulation  2011.666667       NaN
# Pulsar Timing                  1998.400000       NaN
# Pulsation Timing Variations    2007.000000       NaN
# Radial Velocity                2007.518987  2.630699
# Transit                        2011.236776  1.470000
# Transit Timing Variations      2012.500000       NaN
